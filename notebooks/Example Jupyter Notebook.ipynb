# %% [markdown]
# # Example Jupyter Notebook

# %% [markdown]
# This is a sample Jupyter notebook. Notebooks can contain use cases and instructions on how to use the package.
# The notebooks are available for direct download and are also rendered here on the documentation website.

# %%
from IPython.display import Image

# %%
Image("https://cpo.noaa.gov/Portals/0/EasyDNNnews/1006/600600p6226EDNmain6_essmodels.jpg")
